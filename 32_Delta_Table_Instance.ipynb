# %% [markdown]
# - Delta table instance is like a replica of Delta table
# - It is mainly used to perform DML operations
# - It can be created using two ways

# %% [markdown]
# ### Approach 1: using forPath

# %%
from delta.tables import *

DeltaTable.create(spark)\
    .tableName("employee_delta_ins")\
    .addColumn("Emp_name", "STRING")\
    .addColumn("Gender", "STRING")\
    .addColumn("Salary", "INT")\
    .addColumn("Dept", "STRING")\
    .property("Description", "Delta Table Created for Demo")\
    .location("/FileStore/tables/delta1/createtables").execute()
# Out:
# Out[12]: <delta.tables.DeltaTable at 0x7fbcc3cf87c0>

# %%
# %sql
INSERT INTO employee_delta_ins VALUES("Stephen", "M", 8000, "IT"),
                 ("Philip", "M", 2000, "HR"),
                 ("Lara", "F", 6000, "Sales")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
SELECT * From employee_delta_ins
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_name</th><th>Gender</th><th>Salary</th><th>Dept</th></tr></thead><tbody><tr><td>Stephen</td><td>M</td><td>8000</td><td>IT</td></tr><tr><td>Philip</td><td>M</td><td>2000</td><td>HR</td></tr><tr><td>Lara</td><td>F</td><td>6000</td><td>Sales</td></tr></tbody></table></div>

# %%
from delta.tables import *
deltainstance1 = DeltaTable.forPath(spark, "/FileStore/tables/delta1/createtables")

# %%
deltainstance1.toDF().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_name</th><th>Gender</th><th>Salary</th><th>Dept</th></tr></thead><tbody><tr><td>Stephen</td><td>M</td><td>8000</td><td>IT</td></tr><tr><td>Lara</td><td>F</td><td>6000</td><td>Sales</td></tr></tbody></table></div>

# %%
# %sql
DELETE FROM employee_delta_ins WHERE Emp_name = 'Philip' -- this will auto delete in Delta Instance as well
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM employee_delta_ins
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_name</th><th>Gender</th><th>Salary</th><th>Dept</th></tr></thead><tbody><tr><td>Stephen</td><td>M</td><td>8000</td><td>IT</td></tr><tr><td>Lara</td><td>F</td><td>6000</td><td>Sales</td></tr></tbody></table></div>

# %%
deltainstance1.toDF().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_name</th><th>Gender</th><th>Salary</th><th>Dept</th></tr></thead><tbody><tr><td>Stephen</td><td>M</td><td>8000</td><td>IT</td></tr><tr><td>Lara</td><td>F</td><td>6000</td><td>Sales</td></tr></tbody></table></div>

# %%
deltainstance1.delete("Emp_name= 'Stephen'")

# %%
deltainstance1.toDF().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_name</th><th>Gender</th><th>Salary</th><th>Dept</th></tr></thead><tbody><tr><td>Lara</td><td>F</td><td>6000</td><td>Sales</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM employee_delta_ins  -- Auto deleted in table as well!!!
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_name</th><th>Gender</th><th>Salary</th><th>Dept</th></tr></thead><tbody><tr><td>Lara</td><td>F</td><td>6000</td><td>Sales</td></tr></tbody></table></div>

# %% [markdown]
# ### Approach 2: using forName

# %%
deltainstance2 = DeltaTable.forName(spark, "Employee_delta_ins")

# %%
deltainstance2.toDF().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_name</th><th>Gender</th><th>Salary</th><th>Dept</th></tr></thead><tbody><tr><td>Lara</td><td>F</td><td>6000</td><td>Sales</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY employee_delta_ins
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>5</td><td>2025-11-08T09:32:38.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(Emp_name#4963 = Stephen)"])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1285, numCopiedRows -> 1, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2221, numDeletedRows -> 1, scanTimeMs -> 1356, numAddedFiles -> 1, numAddedBytes -> 1291, rewriteTimeMs -> 864)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>4</td><td>2025-11-08T09:32:05.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(Emp_name#4963 = Philip)"])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>3</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 711, numDeletedRows -> 0, scanTimeMs -> 710, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 0)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>3</td><td>2025-11-08T09:26:49.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(Emp_name#5824 = Philip)"])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>2</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1342, numCopiedRows -> 2, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2930, numDeletedRows -> 1, scanTimeMs -> 1623, numAddedFiles -> 1, numAddedBytes -> 1285, rewriteTimeMs -> 1307)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>2</td><td>2025-11-08T09:26:01.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(Emp_name#5436 =  Philip)"])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 708, numDeletedRows -> 0, scanTimeMs -> 666, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 0)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>1</td><td>2025-11-08T09:22:19.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 1342)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>0</td><td>2025-11-08T09:19:58.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>CREATE TABLE</td><td>Map(isManaged -> false, description -> null, partitionBy -> [], properties -> {"Description":"Delta Table Created for Demo"})</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr></tbody></table></div>

# %%
deltainstance2.history().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>5</td><td>2025-11-08T09:32:38.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(Emp_name#4963 = Stephen)"])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1285, numCopiedRows -> 1, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2221, numDeletedRows -> 1, scanTimeMs -> 1356, numAddedFiles -> 1, numAddedBytes -> 1291, rewriteTimeMs -> 864)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>4</td><td>2025-11-08T09:32:05.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(Emp_name#4963 = Philip)"])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>3</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 711, numDeletedRows -> 0, scanTimeMs -> 710, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 0)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>3</td><td>2025-11-08T09:26:49.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(Emp_name#5824 = Philip)"])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>2</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1342, numCopiedRows -> 2, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2930, numDeletedRows -> 1, scanTimeMs -> 1623, numAddedFiles -> 1, numAddedBytes -> 1285, rewriteTimeMs -> 1307)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>2</td><td>2025-11-08T09:26:01.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(Emp_name#5436 =  Philip)"])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 708, numDeletedRows -> 0, scanTimeMs -> 666, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 0)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>1</td><td>2025-11-08T09:22:19.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 1342)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>0</td><td>2025-11-08T09:19:58.000+0000</td><td>6333491925723577</td><td>srishtishetty53@gmail.com</td><td>CREATE TABLE</td><td>Map(isManaged -> false, description -> null, partitionBy -> [], properties -> {"Description":"Delta Table Created for Demo"})</td><td>null</td><td>List(4311939115625821)</td><td>1108-074625-kbcv6j97</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr></tbody></table></div>

# %% [markdown]
# ### Conclusion
# - A DeltaTable instance in PySpark or Databricks is just a reference to a Delta table stored on disk (or cloud storage).
# - All DeltaTable instances and SQL queries access the same underlying table data, so any change is instantly visible to all.
